# %%
using Markdown#hide

# %% [markdown]
# # Monte Carlo (Concrete) Dropout: Bayesian Neural Network (BNN) for a regression task
#
# From [https://github.com/aurelio-amerio/ConcreteDropout/blob/main/examples/Tensorflow/regression_MCDropout.ipynb](https://github.com/aurelio-amerio/ConcreteDropout/blob/main/examples/Tensorflow/regression_MCDropout.ipynb).
# For more information on this BNN implementation, see https://arxiv.org/pdf/1703.04977.pdf

# %%
using Lux
using Optimisers, Zygote
using Random
using MLUtils: DataLoader
using StatsBase
using StatsPlots
using ConcreteDropoutLayer

Random.seed!(MersenneTwister(1))
# Out:
# MersenneTwister(0x1825826fbf8f419a21451a3af6ee7700)

# %% [markdown]
# ## Data

# %%
function gen_data(N; in=1, out=1)
    X = randn(Float32, Q, N)
    σ = 1
    w = 2
    b = 8
    Y = w * ones(out, in) * X .+ b + σ * randn(Float32, out, N)
    return X, Y
end
# Out:
# gen_data (generic function with 1 method)

# %% [markdown]
# ## Neural network functions

# %%
function build_model_dropout(in, out)
    Chain(
        Dense(in => 100, relu),
        Dense(100 => 100, relu),
        ConcreteDropout(),
        Dense(100 => 100, relu),
        ConcreteDropout(),
        Parallel(nothing,
            Chain(Dense(100 => out, relu), ConcreteDropout()),
            Chain(Dense(100 => out, relu), ConcreteDropout())
        )
    )
end

function build_model_dropout(in, out, p)
    Chain(
        Dense(in => 100, relu),
        Dense(100 => 100, relu),
        Dropout(p),
        Dense(100 => 100, relu),
        Dropout(p),
        Parallel(nothing,
            Chain(Dense(100 => out, relu), Dropout(p)),
            Chain(Dense(100 => out, relu), Dropout(p))
        )
    )
end
# Out:
# build_model_dropout (generic function with 2 methods)

# %% [markdown]
# ## Loss functions

# %%
function heteroscedastic_loss(y_pred, y_true)
    μ, log_var = y_pred
    precision = exp.(-log_var)
    return sum(precision .* (y_true - μ) .^ 2 + log_var)
end

function compute_loss_heteroscedastic(model, ps, st, (x, y))
    ŷ, st = model(x, ps, st)
    return heteroscedastic_loss(ŷ, y), st, ()
end
# Out:
# compute_loss_heteroscedastic (generic function with 1 method)

# %% [markdown]
# Version with the added regularization suggested in the original paper. `(names_CD, names_W, input_features), λp, λW` are provided and constant during the training.

# %%
function compute_loss_heteroscedastic_w_reg(model, ps, st, (x, y), (names_CD, names_W, input_features), λp, λW)
    ŷ, st = model(x, ps, st)
    drop_rates, W = get_regularization(ps, names_CD, names_W)

    return heteroscedastic_loss(ŷ, y) + computeCD_reg(drop_rates, W, input_features, λp, λW), st, ()
end
# Out:
# compute_loss_heteroscedastic_w_reg (generic function with 1 method)

# %% [markdown]
# ## Training functions

# %%
function train_step(train_state, xy, compute_loss)
    # Calculate the gradient of the objective
    # with respect to the parameters within the model:
    x, y = xy

    gs, loss, _, train_state = Lux.Experimental.compute_gradients(
                AutoZygote(), compute_loss, (x, y), train_state
    )
    train_state = Lux.Experimental.apply_gradients(train_state, gs)

    return loss, train_state
end


"""
	train(model, epochs, dataset, dataset_val, compute_loss; learning_rate=0.001f0, dev = cpu_device())
Train the `model` and comute at each epoch the training and testing loss
"""
function train(model, epochs, dataset, dataset_val, compute_loss; learning_rate=0.001f0, dev = cpu_device())
    # Set up models
    rng = Xoshiro(0)

    train_state = Lux.Experimental.TrainState(rng, model, Adam(learning_rate); transform_variables=dev)

    ps = train_state.parameters
    st = train_state.states
    model = train_state.model

    # Validation Loss
    losses_train = Float32[]
    x_val, y_val = dataset_val |> dev
    losses_val = Float32[first(compute_loss(model, ps, st, (x_val, y_val)))]
    loss = rand(Float32) # just to define loss in outer loop scope # probably better ways to do that
    best_test_state = train_state

    # Training loop
    for epoch in 1:epochs
        issave = false
        for xy in dataset
            xy = xy |> dev
            loss, train_state = train_step(train_state, xy, compute_loss)
        end
        ps = train_state.parameters
        st = train_state.states
        loss_val = first(compute_loss(model, ps, st, (x_val, y_val)))
        if loss_val < minimum(losses_val)
            best_test_state = train_state
            issave = true
        end
        append!(losses_train, loss)
        append!(losses_val, loss_val)
        @info "Epoch $epoch train_loss = $(round(loss, digits = 4)) validation_loss = $(round(loss_val, digits = 4)) $(issave ? "Best model so far" : " ")"
    end
    return best_test_state, losses_train, losses_val
end
# Out:
# Main.var"##1869".train

# %% [markdown]
# # Data & Settings

# %%
Q = 1
D = 1
n_train = 1000
n_test = 500

using LuxCUDA
dev = gpu_device()

x_train, y_train = gen_data(n_train, in=Q, out=D)

x_test, y_test = gen_data(n_test, in=Q, out=D)

batch_size = 128
epochs = 100
data_train = DataLoader((x_train, y_train), batchsize=batch_size) |> dev
data_test = (x_test, y_test) |> dev
# Out:
# (Float32[1.354469 0.18101627 … 1.2697732 -0.88543224], Float32[11.548834 8.90199 … 9.912215 4.9701724])

# %% [markdown]
# # Training

# %% [markdown]
# ## Dropout Model

# %%
fix_dropout = 0.1
model_CNN_D = build_model_dropout(Q, D, fix_dropout)
# Out:
# Chain(
#     layer_1 = Dense(1 => 100, relu),    # 200 parameters
#     layer_2 = Dense(100 => 100, relu),  # 10_100 parameters
#     layer_3 = Dropout(0.1),
#     layer_4 = Dense(100 => 100, relu),  # 10_100 parameters
#     layer_5 = Dropout(0.1),
#     layer_6 = Parallel(
#         layer_1 = Chain(
#             layer_1 = Dense(100 => 1, relu),  # 101 parameters
#             layer_2 = Dropout(0.1),
#         ),
#         layer_2 = Chain(
#             layer_1 = Dense(100 => 1, relu),  # 101 parameters
#             layer_2 = Dropout(0.1),
#         ),
#     ),
# )         # Total: 20_602 parameters,
#           #        plus 8 states.

# %%
@time "Dropout model" model_state_out_D, loss_train_D, loss_val_D = train(model_CNN_D, epochs, data_train, data_test, compute_loss_heteroscedastic; dev = gpu_device())
# Out:
# [ Info: Epoch 1 train_loss = 6269.6665 validation_loss = 28680.205 Best model so far
# [ Info: Epoch 2 train_loss = 4196.6504 validation_loss = 19205.395 Best model so far
# [ Info: Epoch 3 train_loss = 2356.2808 validation_loss = 10664.658 Best model so far
# [ Info: Epoch 4 train_loss = 1461.8887 validation_loss = 6661.1377 Best model so far
# [ Info: Epoch 5 train_loss = 1088.513 validation_loss = 5445.629 Best model so far
# [ Info: Epoch 6 train_loss = 1046.734 validation_loss = 4758.918 Best model so far
# [ Info: Epoch 7 train_loss = 885.7898 validation_loss = 4150.1304 Best model so far
# [ Info: Epoch 8 train_loss = 855.0356 validation_loss = 3857.2107 Best model so far
# [ Info: Epoch 9 train_loss = 667.144 validation_loss = 3782.265 Best model so far
# [ Info: Epoch 10 train_loss = 871.7429 validation_loss = 3513.9685 Best model so far
# [ Info: Epoch 11 train_loss = 580.6906 validation_loss = 3625.3157
# [ Info: Epoch 12 train_loss = 534.3548 validation_loss = 2815.0928 Best model so far
# [ Info: Epoch 13 train_loss = 540.4942 validation_loss = 2862.9834
# [ Info: Epoch 14 train_loss = 444.6986 validation_loss = 2587.377 Best model so far
# [ Info: Epoch 15 train_loss = 513.5642 validation_loss = 2598.3193
# [ Info: Epoch 16 train_loss = 410.6502 validation_loss = 2652.315
# [ Info: Epoch 17 train_loss = 365.5823 validation_loss = 2076.0112 Best model so far
# [ Info: Epoch 18 train_loss = 344.5116 validation_loss = 1981.0312 Best model so far
# [ Info: Epoch 19 train_loss = 411.75 validation_loss = 2340.1885
# [ Info: Epoch 20 train_loss = 507.2846 validation_loss = 2047.2432
# [ Info: Epoch 21 train_loss = 449.0494 validation_loss = 2033.3792
# [ Info: Epoch 22 train_loss = 637.9888 validation_loss = 1853.22 Best model so far
# [ Info: Epoch 23 train_loss = 314.3852 validation_loss = 1778.305 Best model so far
# [ Info: Epoch 24 train_loss = 364.16 validation_loss = 2516.4912
# [ Info: Epoch 25 train_loss = 546.6212 validation_loss = 1628.2872 Best model so far
# [ Info: Epoch 26 train_loss = 323.7503 validation_loss = 2301.7974
# [ Info: Epoch 27 train_loss = 302.8094 validation_loss = 1740.8364
# [ Info: Epoch 28 train_loss = 303.5589 validation_loss = 1839.9731
# [ Info: Epoch 29 train_loss = 342.9335 validation_loss = 2057.6516
# [ Info: Epoch 30 train_loss = 304.4302 validation_loss = 2285.2856
# [ Info: Epoch 31 train_loss = 380.3513 validation_loss = 1762.3306
# [ Info: Epoch 32 train_loss = 398.5586 validation_loss = 1879.5752
# [ Info: Epoch 33 train_loss = 320.3085 validation_loss = 1881.948
# [ Info: Epoch 34 train_loss = 330.6314 validation_loss = 1695.3956
# [ Info: Epoch 35 train_loss = 345.9212 validation_loss = 1925.0743
# [ Info: Epoch 36 train_loss = 405.426 validation_loss = 1715.2344
# [ Info: Epoch 37 train_loss = 495.1485 validation_loss = 1958.0789
# [ Info: Epoch 38 train_loss = 313.4834 validation_loss = 1743.4358
# [ Info: Epoch 39 train_loss = 370.2369 validation_loss = 1829.4694
# [ Info: Epoch 40 train_loss = 307.4486 validation_loss = 1782.345
# [ Info: Epoch 41 train_loss = 331.8601 validation_loss = 1976.3558
# [ Info: Epoch 42 train_loss = 387.8829 validation_loss = 1913.3444
# [ Info: Epoch 43 train_loss = 302.2222 validation_loss = 1781.6208
# [ Info: Epoch 44 train_loss = 293.4971 validation_loss = 2473.2373
# [ Info: Epoch 45 train_loss = 372.7004 validation_loss = 1805.9462
# [ Info: Epoch 46 train_loss = 452.3916 validation_loss = 1633.1635
# [ Info: Epoch 47 train_loss = 330.8545 validation_loss = 1972.1824
# [ Info: Epoch 48 train_loss = 446.1466 validation_loss = 1908.3832
# [ Info: Epoch 49 train_loss = 322.7519 validation_loss = 1982.4092
# [ Info: Epoch 50 train_loss = 286.558 validation_loss = 1872.571
# [ Info: Epoch 51 train_loss = 342.8511 validation_loss = 2151.9922
# [ Info: Epoch 52 train_loss = 400.8904 validation_loss = 1593.7166 Best model so far
# [ Info: Epoch 53 train_loss = 308.0719 validation_loss = 1674.4543
# [ Info: Epoch 54 train_loss = 368.6759 validation_loss = 1714.133
# [ Info: Epoch 55 train_loss = 371.8796 validation_loss = 1670.6329
# [ Info: Epoch 56 train_loss = 280.447 validation_loss = 1894.9984
# [ Info: Epoch 57 train_loss = 345.8274 validation_loss = 1816.1952
# [ Info: Epoch 58 train_loss = 435.2182 validation_loss = 1861.1548
# [ Info: Epoch 59 train_loss = 430.8112 validation_loss = 1787.3406
# [ Info: Epoch 60 train_loss = 312.6868 validation_loss = 1984.9646
# [ Info: Epoch 61 train_loss = 439.365 validation_loss = 1544.817 Best model so far
# [ Info: Epoch 62 train_loss = 418.0388 validation_loss = 1658.155
# [ Info: Epoch 63 train_loss = 579.5315 validation_loss = 1723.9432
# [ Info: Epoch 64 train_loss = 414.2222 validation_loss = 1467.5085 Best model so far
# [ Info: Epoch 65 train_loss = 325.1982 validation_loss = 2235.8806
# [ Info: Epoch 66 train_loss = 298.0484 validation_loss = 1704.6388
# [ Info: Epoch 67 train_loss = 509.759 validation_loss = 1857.9858
# [ Info: Epoch 68 train_loss = 531.3773 validation_loss = 2158.6416
# [ Info: Epoch 69 train_loss = 439.4492 validation_loss = 1848.8033
# [ Info: Epoch 70 train_loss = 369.9664 validation_loss = 2148.645
# [ Info: Epoch 71 train_loss = 527.4743 validation_loss = 1710.7292
# [ Info: Epoch 72 train_loss = 349.1628 validation_loss = 1863.404
# [ Info: Epoch 73 train_loss = 429.3652 validation_loss = 1724.2281
# [ Info: Epoch 74 train_loss = 337.5904 validation_loss = 1762.1259
# [ Info: Epoch 75 train_loss = 332.871 validation_loss = 1827.3054
# [ Info: Epoch 76 train_loss = 363.1867 validation_loss = 1950.0458
# [ Info: Epoch 77 train_loss = 452.3382 validation_loss = 1884.1648
# [ Info: Epoch 78 train_loss = 371.4267 validation_loss = 1650.2471
# [ Info: Epoch 79 train_loss = 416.4176 validation_loss = 1878.1528
# [ Info: Epoch 80 train_loss = 291.4056 validation_loss = 2015.1923
# [ Info: Epoch 81 train_loss = 343.266 validation_loss = 1903.8706
# [ Info: Epoch 82 train_loss = 545.6057 validation_loss = 1863.8892
# [ Info: Epoch 83 train_loss = 513.8532 validation_loss = 1730.1738
# [ Info: Epoch 84 train_loss = 313.5557 validation_loss = 1514.6434
# [ Info: Epoch 85 train_loss = 462.8064 validation_loss = 1839.5306
# [ Info: Epoch 86 train_loss = 291.674 validation_loss = 2257.8655
# [ Info: Epoch 87 train_loss = 269.2502 validation_loss = 1771.9164
# [ Info: Epoch 88 train_loss = 371.1646 validation_loss = 2033.044
# [ Info: Epoch 89 train_loss = 302.25 validation_loss = 2191.012
# [ Info: Epoch 90 train_loss = 579.6092 validation_loss = 1736.7465
# [ Info: Epoch 91 train_loss = 320.9101 validation_loss = 2520.8953
# [ Info: Epoch 92 train_loss = 493.3171 validation_loss = 1660.6409
# [ Info: Epoch 93 train_loss = 288.4278 validation_loss = 1919.7513
# [ Info: Epoch 94 train_loss = 273.6329 validation_loss = 1718.4384
# [ Info: Epoch 95 train_loss = 294.4415 validation_loss = 1770.554
# [ Info: Epoch 96 train_loss = 399.2839 validation_loss = 2263.5942
# [ Info: Epoch 97 train_loss = 456.296 validation_loss = 1648.4978
# [ Info: Epoch 98 train_loss = 284.7316 validation_loss = 2180.694
# [ Info: Epoch 99 train_loss = 315.6492 validation_loss = 1981.7974
# [ Info: Epoch 100 train_loss = 436.5654 validation_loss = 1949.4952
# Dropout model: 2.302857 seconds (7.32 M allocations: 352.244 MiB, 2.34% gc time, 28.30% compilation time)
# (Lux.Experimental.TrainState{Nothing, Nothing, Chain{@NamedTuple{layer_1::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dropout{Float64, Colon}, layer_4::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_5::Dropout{Float64, Colon}, layer_6::Parallel{Nothing, @NamedTuple{layer_1::Chain{@NamedTuple{layer_1::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dropout{Float64, Colon}}, Nothing}, layer_2::Chain{@NamedTuple{layer_1::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dropout{Float64, Colon}}, Nothing}}, Nothing}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_2::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_3::@NamedTuple{}, layer_4::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_5::@NamedTuple{}, layer_6::@NamedTuple{layer_1::@NamedTuple{layer_1::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_2::@NamedTuple{}}, layer_2::@NamedTuple{layer_1::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_2::@NamedTuple{}}}}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{rng::Xoshiro, training::Val{true}}, layer_4::@NamedTuple{}, layer_5::@NamedTuple{rng::Xoshiro, training::Val{true}}, layer_6::@NamedTuple{layer_1::@NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{rng::Xoshiro, training::Val{true}}}, layer_2::@NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{rng::Xoshiro, training::Val{true}}}}}, Adam, @NamedTuple{layer_1::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_2::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_3::@NamedTuple{}, layer_4::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_5::@NamedTuple{}, layer_6::@NamedTuple{layer_1::@NamedTuple{layer_1::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_2::@NamedTuple{}}, layer_2::@NamedTuple{layer_1::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_2::@NamedTuple{}}}}}(nothing, nothing, Chain{@NamedTuple{layer_1::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dropout{Float64, Colon}, layer_4::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_5::Dropout{Float64, Colon}, layer_6::Parallel{Nothing, @NamedTuple{layer_1::C ...

# %% [markdown]
# ## Concrete Dropout Model

# %% [markdown]
# ### Without regularization

# %%
model_CNN_CD = build_model_dropout(Q, D)
# Out:
# Chain(
#     layer_1 = Dense(1 => 100, relu),    # 200 parameters
#     layer_2 = Dense(100 => 100, relu),  # 10_100 parameters
#     layer_3 = ConcreteDropout(),        # 1 parameters, plus 2
#     layer_4 = Dense(100 => 100, relu),  # 10_100 parameters
#     layer_5 = ConcreteDropout(),        # 1 parameters, plus 2
#     layer_6 = Parallel(
#         layer_1 = Chain(
#             layer_1 = Dense(100 => 1, relu),  # 101 parameters
#             layer_2 = ConcreteDropout(),  # 1 parameters, plus 2
#         ),
#         layer_2 = Chain(
#             layer_1 = Dense(100 => 1, relu),  # 101 parameters
#             layer_2 = ConcreteDropout(),  # 1 parameters, plus 2
#         ),
#     ),
# )         # Total: 20_606 parameters,
#           #        plus 8 states.

# %%
@time "Concrete Dropout model" model_state_out_CD, loss_train_CD, loss_val_CD = train(model_CNN_CD, epochs, data_train, data_test, compute_loss_heteroscedastic; dev = gpu_device())
# Out:
# [ Info: Epoch 1 train_loss = 5089.705 validation_loss = 23575.932 Best model so far
# [ Info: Epoch 2 train_loss = 3744.5613 validation_loss = 15090.98 Best model so far
# [ Info: Epoch 3 train_loss = 1762.1666 validation_loss = 9186.246 Best model so far
# [ Info: Epoch 4 train_loss = 1115.263 validation_loss = 5685.2524 Best model so far
# [ Info: Epoch 5 train_loss = 1230.8403 validation_loss = 6053.6406
# [ Info: Epoch 6 train_loss = 968.0298 validation_loss = 4781.3516 Best model so far
# [ Info: Epoch 7 train_loss = 1187.6045 validation_loss = 4843.877
# [ Info: Epoch 8 train_loss = 711.7212 validation_loss = 4187.9097 Best model so far
# [ Info: Epoch 9 train_loss = 941.0627 validation_loss = 4074.8933 Best model so far
# [ Info: Epoch 10 train_loss = 696.8652 validation_loss = 3799.834 Best model so far
# [ Info: Epoch 11 train_loss = 615.4882 validation_loss = 3366.636 Best model so far
# [ Info: Epoch 12 train_loss = 532.9914 validation_loss = 3036.982 Best model so far
# [ Info: Epoch 13 train_loss = 548.2688 validation_loss = 2806.3867 Best model so far
# [ Info: Epoch 14 train_loss = 421.58 validation_loss = 2460.9778 Best model so far
# [ Info: Epoch 15 train_loss = 391.6481 validation_loss = 2236.4058 Best model so far
# [ Info: Epoch 16 train_loss = 374.2479 validation_loss = 1988.6846 Best model so far
# [ Info: Epoch 17 train_loss = 347.2748 validation_loss = 2062.6345
# [ Info: Epoch 18 train_loss = 313.2564 validation_loss = 1742.4388 Best model so far
# [ Info: Epoch 19 train_loss = 360.4338 validation_loss = 2033.3374
# [ Info: Epoch 20 train_loss = 298.0942 validation_loss = 1693.0422 Best model so far
# [ Info: Epoch 21 train_loss = 448.3448 validation_loss = 1927.6296
# [ Info: Epoch 22 train_loss = 327.9012 validation_loss = 1788.136
# [ Info: Epoch 23 train_loss = 367.173 validation_loss = 1713.3096
# [ Info: Epoch 24 train_loss = 511.9298 validation_loss = 1635.6383 Best model so far
# [ Info: Epoch 25 train_loss = 267.0242 validation_loss = 1620.5544 Best model so far
# [ Info: Epoch 26 train_loss = 458.6939 validation_loss = 1499.3502 Best model so far
# [ Info: Epoch 27 train_loss = 304.6649 validation_loss = 1463.5021 Best model so far
# [ Info: Epoch 28 train_loss = 294.6326 validation_loss = 1629.6411
# [ Info: Epoch 29 train_loss = 457.9769 validation_loss = 1750.3704
# [ Info: Epoch 30 train_loss = 467.998 validation_loss = 1514.6255
# [ Info: Epoch 31 train_loss = 338.3648 validation_loss = 1741.1838
# [ Info: Epoch 32 train_loss = 276.4993 validation_loss = 1584.1324
# [ Info: Epoch 33 train_loss = 279.2166 validation_loss = 1540.9731
# [ Info: Epoch 34 train_loss = 340.6876 validation_loss = 1631.3995
# [ Info: Epoch 35 train_loss = 442.7988 validation_loss = 1640.6321
# [ Info: Epoch 36 train_loss = 388.28 validation_loss = 1919.0796
# [ Info: Epoch 37 train_loss = 410.1856 validation_loss = 1466.2212
# [ Info: Epoch 38 train_loss = 321.7382 validation_loss = 1793.4688
# [ Info: Epoch 39 train_loss = 570.3082 validation_loss = 1524.0271
# [ Info: Epoch 40 train_loss = 384.418 validation_loss = 1630.5338
# [ Info: Epoch 41 train_loss = 267.2551 validation_loss = 1524.8231
# [ Info: Epoch 42 train_loss = 284.8336 validation_loss = 1457.4414 Best model so far
# [ Info: Epoch 43 train_loss = 240.9109 validation_loss = 1451.099 Best model so far
# [ Info: Epoch 44 train_loss = 341.4572 validation_loss = 1577.4851
# [ Info: Epoch 45 train_loss = 252.3168 validation_loss = 1486.4316
# [ Info: Epoch 46 train_loss = 266.8338 validation_loss = 1377.2008 Best model so far
# [ Info: Epoch 47 train_loss = 325.4616 validation_loss = 1540.1478
# [ Info: Epoch 48 train_loss = 370.353 validation_loss = 1429.6993
# [ Info: Epoch 49 train_loss = 275.0882 validation_loss = 1383.7053
# [ Info: Epoch 50 train_loss = 227.7248 validation_loss = 1576.3071
# [ Info: Epoch 51 train_loss = 229.6542 validation_loss = 1714.2532
# [ Info: Epoch 52 train_loss = 245.3666 validation_loss = 1414.6213
# [ Info: Epoch 53 train_loss = 237.2724 validation_loss = 1488.8682
# [ Info: Epoch 54 train_loss = 338.4742 validation_loss = 1314.5094 Best model so far
# [ Info: Epoch 55 train_loss = 312.0315 validation_loss = 1520.5201
# [ Info: Epoch 56 train_loss = 275.6854 validation_loss = 1464.8596
# [ Info: Epoch 57 train_loss = 246.7538 validation_loss = 1536.8418
# [ Info: Epoch 58 train_loss = 342.4151 validation_loss = 1444.9144
# [ Info: Epoch 59 train_loss = 294.4504 validation_loss = 1752.4052
# [ Info: Epoch 60 train_loss = 281.1235 validation_loss = 1633.0619
# [ Info: Epoch 61 train_loss = 302.5054 validation_loss = 1449.1216
# [ Info: Epoch 62 train_loss = 223.04 validation_loss = 1619.112
# [ Info: Epoch 63 train_loss = 230.5631 validation_loss = 1527.258
# [ Info: Epoch 64 train_loss = 242.2914 validation_loss = 1389.8113
# [ Info: Epoch 65 train_loss = 252.1509 validation_loss = 1291.718 Best model so far
# [ Info: Epoch 66 train_loss = 358.5345 validation_loss = 1416.185
# [ Info: Epoch 67 train_loss = 311.1698 validation_loss = 1473.2797
# [ Info: Epoch 68 train_loss = 436.96 validation_loss = 1423.4474
# [ Info: Epoch 69 train_loss = 318.9828 validation_loss = 1468.308
# [ Info: Epoch 70 train_loss = 242.6946 validation_loss = 1426.137
# [ Info: Epoch 71 train_loss = 323.1391 validation_loss = 1380.1681
# [ Info: Epoch 72 train_loss = 322.5132 validation_loss = 1348.7894
# [ Info: Epoch 73 train_loss = 324.4683 validation_loss = 1241.0771 Best model so far
# [ Info: Epoch 74 train_loss = 271.2374 validation_loss = 1391.4917
# [ Info: Epoch 75 train_loss = 281.2251 validation_loss = 1761.7863
# [ Info: Epoch 76 train_loss = 328.4546 validation_loss = 1596.0078
# [ Info: Epoch 77 train_loss = 262.6404 validation_loss = 1410.0023
# [ Info: Epoch 78 train_loss = 311.3431 validation_loss = 1515.8992
# [ Info: Epoch 79 train_loss = 272.7392 validation_loss = 1587.3723
# [ Info: Epoch 80 train_loss = 320.1488 validation_loss = 1360.1116
# [ Info: Epoch 81 train_loss = 275.7014 validation_loss = 1351.6707
# [ Info: Epoch 82 train_loss = 251.7655 validation_loss = 1622.1565
# [ Info: Epoch 83 train_loss = 265.5337 validation_loss = 1463.1477
# [ Info: Epoch 84 train_loss = 232.1248 validation_loss = 1604.3557
# [ Info: Epoch 85 train_loss = 391.1597 validation_loss = 1557.9539
# [ Info: Epoch 86 train_loss = 230.9309 validation_loss = 1238.8876 Best model so far
# [ Info: Epoch 87 train_loss = 282.7744 validation_loss = 1336.573
# [ Info: Epoch 88 train_loss = 227.8474 validation_loss = 1282.7556
# [ Info: Epoch 89 train_loss = 396.2442 validation_loss = 1264.6783
# [ Info: Epoch 90 train_loss = 293.29 validation_loss = 1675.1211
# [ Info: Epoch 91 train_loss = 264.631 validation_loss = 1302.6365
# [ Info: Epoch 92 train_loss = 286.6096 validation_loss = 1461.4075
# [ Info: Epoch 93 train_loss = 252.1734 validation_loss = 1359.7788
# [ Info: Epoch 94 train_loss = 298.2614 validation_loss = 1424.5979
# [ Info: Epoch 95 train_loss = 301.4874 validation_loss = 1340.7786
# [ Info: Epoch 96 train_loss = 618.5475 validation_loss = 1316.2158
# [ Info: Epoch 97 train_loss = 405.0565 validation_loss = 1225.9104 Best model so far
# [ Info: Epoch 98 train_loss = 324.9786 validation_loss = 1431.5922
# [ Info: Epoch 99 train_loss = 229.8103 validation_loss = 1168.223 Best model so far
# [ Info: Epoch 100 train_loss = 261.7155 validation_loss = 1319.4166
# Concrete Dropout model: 3.981087 seconds (15.55 M allocations: 548.596 MiB, 2.16% gc time, 14.43% compilation time)
# (Lux.Experimental.TrainState{Nothing, Nothing, Chain{@NamedTuple{layer_1::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_3::ConcreteDropout{Float32, Colon, Tuple{Float32, Float32}}, layer_4::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_5::ConcreteDropout{Float32, Colon, Tuple{Float32, Float32}}, layer_6::Parallel{Nothing, @NamedTuple{layer_1::Chain{@NamedTuple{layer_1::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_2::ConcreteDropout{Float32, Colon, Tuple{Float32, Float32}}}, Nothing}, layer_2::Chain{@NamedTuple{layer_1::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_2::ConcreteDropout{Float32, Colon, Tuple{Float32, Float32}}}, Nothing}}, Nothing}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_2::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_3::@NamedTuple{p_logit::CuArray{Float32, 1, CUDA.DeviceMemory}}, layer_4::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_5::@NamedTuple{p_logit::CuArray{Float32, 1, CUDA.DeviceMemory}}, layer_6::@NamedTuple{layer_1::@NamedTuple{layer_1::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_2::@NamedTuple{p_logit::CuArray{Float32, 1, CUDA.DeviceMemory}}}, layer_2::@NamedTuple{layer_1::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_2::@NamedTuple{p_logit::CuArray{Float32, 1, CUDA.DeviceMemory}}}}}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{rng::Xoshiro, training::Val{true}}, layer_4::@NamedTuple{}, layer_5::@NamedTuple{rng::Xoshiro, training::Val{true}}, layer_6::@NamedTuple{layer_1::@NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{rng::Xoshiro, training::Val{true}}}, layer_2::@NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{rng::Xoshiro, training::Val{true}}}}}, Adam, @NamedTuple{layer_1::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_2::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_3::@NamedTuple{p_logit::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 1, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_4::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_5::@NamedTuple{p_logit::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 1, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_6::@NamedTuple{layer_1::@NamedTuple{layer_1::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_2::@NamedTuple{p_logit::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 1, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Float32, Float3 ...

# %% [markdown]
# ### With regularization

# %%
wr = get_weight_regularizer(n_train, l=1.0f-2, τ=1.0f0)
dr = get_dropout_regularizer(n_train, τ=1.0f0, cross_entropy_loss=false)
# Out:
# 0.002f0

# %%
p_cd, w_cd, KK = regularization_infos(Lux.Experimental.TrainState(Xoshiro(0), model_CNN_CD, Adam(0.1f0); transform_variables=dev))
@time "Concrete Dropout model reg" model_state_out_CD_reg, loss_train_CD_reg, loss_val_CD_reg = train(model_CNN_CD, epochs, data_train, data_test, (model, ps, st, xy) -> compute_loss_heteroscedastic_w_reg(model, ps, st, xy, (p_cd, w_cd, KK), dr, wr); dev = gpu_device())
# Out:
# [ Info: Epoch 1 train_loss = 5089.1523 validation_loss = 23573.828 Best model so far
# [ Info: Epoch 2 train_loss = 3743.7925 validation_loss = 15087.747 Best model so far
# [ Info: Epoch 3 train_loss = 1761.2758 validation_loss = 9182.826 Best model so far
# [ Info: Epoch 4 train_loss = 1113.5056 validation_loss = 5679.8174 Best model so far
# [ Info: Epoch 5 train_loss = 1229.9988 validation_loss = 6051.621
# [ Info: Epoch 6 train_loss = 968.438 validation_loss = 4783.9917 Best model so far
# [ Info: Epoch 7 train_loss = 1188.3053 validation_loss = 4848.7017
# [ Info: Epoch 8 train_loss = 714.0696 validation_loss = 4200.2646 Best model so far
# [ Info: Epoch 9 train_loss = 944.0378 validation_loss = 4094.2493 Best model so far
# [ Info: Epoch 10 train_loss = 698.5442 validation_loss = 3818.2373 Best model so far
# [ Info: Epoch 11 train_loss = 617.476 validation_loss = 3371.327 Best model so far
# [ Info: Epoch 12 train_loss = 530.8039 validation_loss = 3018.2507 Best model so far
# [ Info: Epoch 13 train_loss = 540.2489 validation_loss = 2771.5479 Best model so far
# [ Info: Epoch 14 train_loss = 412.6736 validation_loss = 2414.5115 Best model so far
# [ Info: Epoch 15 train_loss = 380.277 validation_loss = 2192.3286 Best model so far
# [ Info: Epoch 16 train_loss = 371.509 validation_loss = 1982.7844 Best model so far
# [ Info: Epoch 17 train_loss = 347.9116 validation_loss = 2069.5215
# [ Info: Epoch 18 train_loss = 318.9565 validation_loss = 1742.852 Best model so far
# [ Info: Epoch 19 train_loss = 371.1276 validation_loss = 2052.334
# [ Info: Epoch 20 train_loss = 300.5259 validation_loss = 1721.6172 Best model so far
# [ Info: Epoch 21 train_loss = 456.6892 validation_loss = 1947.1844
# [ Info: Epoch 22 train_loss = 325.7954 validation_loss = 1818.513
# [ Info: Epoch 23 train_loss = 369.1346 validation_loss = 1721.0966 Best model so far
# [ Info: Epoch 24 train_loss = 514.7328 validation_loss = 1652.0785 Best model so far
# [ Info: Epoch 25 train_loss = 270.3822 validation_loss = 1634.9393 Best model so far
# [ Info: Epoch 26 train_loss = 463.6197 validation_loss = 1498.2775 Best model so far
# [ Info: Epoch 27 train_loss = 305.7179 validation_loss = 1477.3508 Best model so far
# [ Info: Epoch 28 train_loss = 294.3737 validation_loss = 1620.2942
# [ Info: Epoch 29 train_loss = 459.7578 validation_loss = 1756.4376
# [ Info: Epoch 30 train_loss = 470.891 validation_loss = 1511.3739
# [ Info: Epoch 31 train_loss = 341.2834 validation_loss = 1752.0382
# [ Info: Epoch 32 train_loss = 269.7354 validation_loss = 1583.853
# [ Info: Epoch 33 train_loss = 283.0439 validation_loss = 1566.2417
# [ Info: Epoch 34 train_loss = 340.5942 validation_loss = 1615.1307
# [ Info: Epoch 35 train_loss = 449.2488 validation_loss = 1642.1351
# [ Info: Epoch 36 train_loss = 392.0868 validation_loss = 1932.9734
# [ Info: Epoch 37 train_loss = 395.5025 validation_loss = 1460.3649 Best model so far
# [ Info: Epoch 38 train_loss = 320.5484 validation_loss = 1790.367
# [ Info: Epoch 39 train_loss = 560.4188 validation_loss = 1515.5903
# [ Info: Epoch 40 train_loss = 382.8816 validation_loss = 1621.2393
# [ Info: Epoch 41 train_loss = 267.2955 validation_loss = 1530.7197
# [ Info: Epoch 42 train_loss = 284.356 validation_loss = 1450.9508 Best model so far
# [ Info: Epoch 43 train_loss = 239.3237 validation_loss = 1447.5435 Best model so far
# [ Info: Epoch 44 train_loss = 341.8923 validation_loss = 1592.2762
# [ Info: Epoch 45 train_loss = 253.7639 validation_loss = 1470.6194
# [ Info: Epoch 46 train_loss = 267.97 validation_loss = 1394.0618 Best model so far
# [ Info: Epoch 47 train_loss = 322.6616 validation_loss = 1516.9497
# [ Info: Epoch 48 train_loss = 369.4656 validation_loss = 1421.5669
# [ Info: Epoch 49 train_loss = 271.7997 validation_loss = 1383.3733 Best model so far
# [ Info: Epoch 50 train_loss = 231.3116 validation_loss = 1568.3163
# [ Info: Epoch 51 train_loss = 234.3921 validation_loss = 1704.1656
# [ Info: Epoch 52 train_loss = 249.7632 validation_loss = 1423.0
# [ Info: Epoch 53 train_loss = 242.2383 validation_loss = 1497.1681
# [ Info: Epoch 54 train_loss = 339.9368 validation_loss = 1334.1744 Best model so far
# [ Info: Epoch 55 train_loss = 315.8098 validation_loss = 1513.6853
# [ Info: Epoch 56 train_loss = 277.2403 validation_loss = 1458.0077
# [ Info: Epoch 57 train_loss = 248.7552 validation_loss = 1553.4531
# [ Info: Epoch 58 train_loss = 336.6075 validation_loss = 1441.5182
# [ Info: Epoch 59 train_loss = 294.6017 validation_loss = 1747.2415
# [ Info: Epoch 60 train_loss = 280.7528 validation_loss = 1616.991
# [ Info: Epoch 61 train_loss = 303.2586 validation_loss = 1447.7294
# [ Info: Epoch 62 train_loss = 225.776 validation_loss = 1629.3578
# [ Info: Epoch 63 train_loss = 230.7939 validation_loss = 1525.5853
# [ Info: Epoch 64 train_loss = 246.5748 validation_loss = 1399.2723
# [ Info: Epoch 65 train_loss = 249.8475 validation_loss = 1293.3644 Best model so far
# [ Info: Epoch 66 train_loss = 351.2716 validation_loss = 1414.9524
# [ Info: Epoch 67 train_loss = 313.0214 validation_loss = 1469.5211
# [ Info: Epoch 68 train_loss = 435.4822 validation_loss = 1412.2678
# [ Info: Epoch 69 train_loss = 315.2717 validation_loss = 1473.7457
# [ Info: Epoch 70 train_loss = 248.7152 validation_loss = 1427.4385
# [ Info: Epoch 71 train_loss = 322.3161 validation_loss = 1364.138
# [ Info: Epoch 72 train_loss = 317.9862 validation_loss = 1353.5391
# [ Info: Epoch 73 train_loss = 320.9611 validation_loss = 1254.1945 Best model so far
# [ Info: Epoch 74 train_loss = 270.5698 validation_loss = 1391.0659
# [ Info: Epoch 75 train_loss = 279.6627 validation_loss = 1779.2362
# [ Info: Epoch 76 train_loss = 333.9808 validation_loss = 1592.928
# [ Info: Epoch 77 train_loss = 258.8887 validation_loss = 1409.7551
# [ Info: Epoch 78 train_loss = 317.3375 validation_loss = 1529.2323
# [ Info: Epoch 79 train_loss = 272.0904 validation_loss = 1587.4794
# [ Info: Epoch 80 train_loss = 319.5426 validation_loss = 1361.9015
# [ Info: Epoch 81 train_loss = 277.2749 validation_loss = 1348.1852
# [ Info: Epoch 82 train_loss = 256.3094 validation_loss = 1629.1222
# [ Info: Epoch 83 train_loss = 265.6783 validation_loss = 1463.7067
# [ Info: Epoch 84 train_loss = 231.1648 validation_loss = 1600.2473
# [ Info: Epoch 85 train_loss = 390.8927 validation_loss = 1568.6346
# [ Info: Epoch 86 train_loss = 231.8984 validation_loss = 1245.2069 Best model so far
# [ Info: Epoch 87 train_loss = 281.597 validation_loss = 1349.1143
# [ Info: Epoch 88 train_loss = 227.6818 validation_loss = 1295.249
# [ Info: Epoch 89 train_loss = 393.2536 validation_loss = 1257.3674
# [ Info: Epoch 90 train_loss = 294.9767 validation_loss = 1690.216
# [ Info: Epoch 91 train_loss = 265.9982 validation_loss = 1309.3807
# [ Info: Epoch 92 train_loss = 291.2926 validation_loss = 1466.6075
# [ Info: Epoch 93 train_loss = 251.9676 validation_loss = 1354.6652
# [ Info: Epoch 94 train_loss = 301.6668 validation_loss = 1432.6149
# [ Info: Epoch 95 train_loss = 307.9608 validation_loss = 1347.6154
# [ Info: Epoch 96 train_loss = 616.1078 validation_loss = 1321.2147
# [ Info: Epoch 97 train_loss = 399.3602 validation_loss = 1233.0437 Best model so far
# [ Info: Epoch 98 train_loss = 321.2248 validation_loss = 1424.7687
# [ Info: Epoch 99 train_loss = 231.038 validation_loss = 1170.3854 Best model so far
# [ Info: Epoch 100 train_loss = 263.7086 validation_loss = 1319.5734
# Concrete Dropout model reg: 19.522475 seconds (54.73 M allocations: 2.662 GiB, 2.33% gc time, 59.06% compilation time)
# (Lux.Experimental.TrainState{Nothing, Nothing, Chain{@NamedTuple{layer_1::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_3::ConcreteDropout{Float32, Colon, Tuple{Float32, Float32}}, layer_4::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_5::ConcreteDropout{Float32, Colon, Tuple{Float32, Float32}}, layer_6::Parallel{Nothing, @NamedTuple{layer_1::Chain{@NamedTuple{layer_1::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_2::ConcreteDropout{Float32, Colon, Tuple{Float32, Float32}}}, Nothing}, layer_2::Chain{@NamedTuple{layer_1::Dense{true, typeof(relu), typeof(glorot_uniform), typeof(zeros32)}, layer_2::ConcreteDropout{Float32, Colon, Tuple{Float32, Float32}}}, Nothing}}, Nothing}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_2::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_3::@NamedTuple{p_logit::CuArray{Float32, 1, CUDA.DeviceMemory}}, layer_4::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_5::@NamedTuple{p_logit::CuArray{Float32, 1, CUDA.DeviceMemory}}, layer_6::@NamedTuple{layer_1::@NamedTuple{layer_1::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_2::@NamedTuple{p_logit::CuArray{Float32, 1, CUDA.DeviceMemory}}}, layer_2::@NamedTuple{layer_1::@NamedTuple{weight::CuArray{Float32, 2, CUDA.DeviceMemory}, bias::CuArray{Float32, 2, CUDA.DeviceMemory}}, layer_2::@NamedTuple{p_logit::CuArray{Float32, 1, CUDA.DeviceMemory}}}}}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{rng::Xoshiro, training::Val{true}}, layer_4::@NamedTuple{}, layer_5::@NamedTuple{rng::Xoshiro, training::Val{true}}, layer_6::@NamedTuple{layer_1::@NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{rng::Xoshiro, training::Val{true}}}, layer_2::@NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{rng::Xoshiro, training::Val{true}}}}}, Adam, @NamedTuple{layer_1::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_2::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_3::@NamedTuple{p_logit::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 1, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_4::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_5::@NamedTuple{p_logit::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 1, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_6::@NamedTuple{layer_1::@NamedTuple{layer_1::@NamedTuple{weight::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}, bias::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 2, CUDA.DeviceMemory}, CuArray{Float32, 2, CUDA.DeviceMemory}, Tuple{Float32, Float32}}}}, layer_2::@NamedTuple{p_logit::Optimisers.Leaf{Adam, Tuple{CuArray{Float32, 1, CUDA.DeviceMemory}, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Float32, Float3 ...

# %% [markdown]
# # Result

# %% [markdown]
# ## Training loss

# %%
begin
    p_train = plot(loss_train_D, label="Dropout($fix_dropout)", title="Train loss")
    plot!(loss_train_CD, label="ConcreteDropout")
    plot!(loss_train_CD_reg, label="ConcreteDropout + reg", alpha = 0.7)
    xlabel!("Epoch")
    ylabel!("loss", yscale = :log10)
    p_test = plot(loss_val_D, label="test Dropout($fix_dropout)", title="Test loss")
    plot!(loss_val_CD, label="test ConcreteDropout")
    plot!(loss_val_CD_reg, label="test ConcreteDropout + reg", alpha = 0.7)
    xlabel!("Epoch")
    ylabel!("loss", yscale = :log10)
    plot(p_train, p_test)
end
# Out:
# Plot{Plots.GRBackend() n=6}

# %% [markdown]
# ## Monte Carlo predictions

# %%
"""
	MC_predict(model, X::AbstractArray{T}; n_samples=1000, kwargs...)
For each X it returns `n_samples` monte carlo simulations where the randomness comes from the (Concrete)Dropout layers.
"""
function MC_predict(model_state, X::AbstractArray, n_samples=1000; dev = gpu_device(), dim_out = model_state.model[end].layers[1].out_dims)
    st = model_state.states
    ps = model_state.parameters
    model = model_state.model

    dim_N = ndims(X)
    mean_arr = similar(X, dim_out, size(X, dim_N))
    std_dev_arr = similar(X, dim_out, size(X, dim_N))

    X = X |> dev
    X_in = similar(X, size(X)[1:end-1]..., n_samples) |> dev


    for (i, x) in enumerate(eachslice(X, dims=dim_N, drop = false))
        X_in .= x
        predictions, st = model(X_in, ps, st)
        θs_MC, logvars = predictions |> cpu_device()

        θ_hat = mean(θs_MC, dims=2) # predictive_mean

        θ2_hat = mean(θs_MC .^ 2, dims=2) # θ2_hat = mean(θs_MC' * θs_MC, dims=2)
        var_mean = mean(exp.(logvars), dims=2) # aleatoric_uncertainty
        total_var = θ2_hat - θ_hat .^ 2 + var_mean
        std_dev = sqrt.(total_var)

        mean_arr[:, i] .= θ_hat
        std_dev_arr[:, i] .= std_dev
    end

    return mean_arr, std_dev_arr
end

y_pred, y_std = MC_predict(model_state_out_CD_reg, x_test, dev = dev, dim_out = D)
y_pred_d, y_std_d = MC_predict(model_state_out_D, x_test, dev = dev, dim_out = D)
# Out:
# (Float32[9.883528 7.593921 … 9.666417 5.392767], Float32[4.6814218 3.800577 … 4.685681 2.8670635])

# %% [markdown]
# Plot prediction plus standard deviation (aleatoric + epistemic)

# %%
begin
    argsort = sortperm(x_test, dims=2)
    x_sorted = x_test[argsort]'
    y_true_sorted = y_test[argsort]'

    plot(x_sorted, y_true_sorted, label="y_test", lw = 2)
    plot!(x_sorted, y_pred_d[argsort]', ribbon=y_std_d[argsort]', label="ŷ ± σ Dropout(0.1)", alpha=0.4, lw = 1.5)
    plot!(x_sorted, y_pred[argsort]', ribbon=y_std[argsort]', label="ŷ ± σ ConcreteDropout", alpha=0.4, lw = 1.5)
end
# Out:
# Plot{Plots.GRBackend() n=3}

# %% [markdown]
# Print all learned Dropout rates.

# %%
function print_p_CD(l, ps, st, name)
    if l isa ConcreteDropout
        println("p = $(sigmoid(ps.p_logit)) of $name")
    end
    return l, ps, st
end;
Lux.Experimental.@layer_map print_p_CD model_state_out_CD.model model_state_out_CD.parameters model_state_out_CD.parameters;
# Out:
# p = Float32[0.074241795] of model_state_out_CD.model.layers.layer_3
# p = Float32[0.06898067] of model_state_out_CD.model.layers.layer_5
# p = Float32[0.056299094] of model_state_out_CD.model.layers.layer_6.layers.layer_1.layers.layer_2
# p = Float32[0.083094686] of model_state_out_CD.model.layers.layer_6.layers.layer_2.layers.layer_2

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
